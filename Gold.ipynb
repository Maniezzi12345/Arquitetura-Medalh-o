# %%
# %%sql
# CREATE OR REPLACE VIEW paises_gold_vw AS
# SELECT
#     i.codigo_iso_2 AS codigo_iso_2,
#     CASE
#         WHEN t.nome_pais = 'Andorra' THEN 'Andorra'
#         WHEN t.nome_pais = 'Albania' THEN 'Albânia'
#         WHEN t.nome_pais = 'Austria' THEN 'Áustria'
#         WHEN t.nome_pais = 'Bosnia And Herzegovina' THEN 'Bósnia e Herzegovina'
#         WHEN t.nome_pais = 'Belgium' THEN 'Bélgica'
#         WHEN t.nome_pais = 'Bulgaria' THEN 'Bulgária'
#         WHEN t.nome_pais = 'Belarus' THEN 'Bielorrússia'
#         WHEN t.nome_pais = 'Switzerland' THEN 'Suíça'
#         WHEN t.nome_pais = 'Cyprus' THEN 'Chipre'
#         WHEN t.nome_pais = 'Czechia' THEN 'Tchéquia'
#         WHEN t.nome_pais = 'Germany' THEN 'Alemanha'
#         WHEN t.nome_pais = 'Denmark' THEN 'Dinamarca'
#         WHEN t.nome_pais = 'Estonia' THEN 'Estônia'
#         WHEN t.nome_pais = 'Spain' THEN 'Espanha'
#         WHEN t.nome_pais = 'Finland' THEN 'Finlândia'
#         WHEN t.nome_pais = 'France' THEN 'França'
#         WHEN t.nome_pais = 'United Kingdom' THEN 'Reino Unido'
#         WHEN t.nome_pais = 'Greece' THEN 'Grécia'
#         WHEN t.nome_pais = 'Croatia' THEN 'Croácia'
#         WHEN t.nome_pais = 'Hungary' THEN 'Hungria'
#         WHEN t.nome_pais = 'Ireland' THEN 'Irlanda'
#         WHEN t.nome_pais = 'Iceland' THEN 'Islândia'
#         WHEN t.nome_pais = 'Italy' THEN 'Itália'
#         WHEN t.nome_pais = 'Liechtenstein' THEN 'Liechtenstein'
#         WHEN t.nome_pais = 'Lithuania' THEN 'Lituânia'
#         WHEN t.nome_pais = 'Luxembourg' THEN 'Luxemburgo'
#         WHEN t.nome_pais = 'Latvia' THEN 'Letônia'
#         WHEN t.nome_pais = 'Monaco' THEN 'Mônaco'
#         WHEN t.nome_pais = 'Moldova' THEN 'Moldávia'
#         WHEN t.nome_pais = 'Montenegro' THEN 'Montenegro'
#         WHEN t.nome_pais = 'North Macedonia' THEN 'Macedônia do Norte'
#         WHEN t.nome_pais = 'Malta' THEN 'Malta'
#         WHEN t.nome_pais = 'Netherlands' THEN 'Países Baixos'
#         WHEN t.nome_pais = 'Norway' THEN 'Noruega'
#         WHEN t.nome_pais = 'Poland' THEN 'Polônia'
#         WHEN t.nome_pais = 'Portugal' THEN 'Portugal'
#         WHEN t.nome_pais = 'Romania' THEN 'Romênia'
#         WHEN t.nome_pais = 'Serbia' THEN 'Sérvia'
#         WHEN t.nome_pais = 'Russia' THEN 'Rússia'
#         WHEN t.nome_pais = 'Sweden' THEN 'Suécia'
#         WHEN t.nome_pais = 'Slovenia' THEN 'Eslovênia'
#         WHEN t.nome_pais = 'Slovakia' THEN 'Eslováquia'
#         WHEN t.nome_pais = 'San Marino' THEN 'San Marino'
#         WHEN t.nome_pais = 'Ukraine' THEN 'Ucrânia'
#         WHEN t.nome_pais = 'Vatican City' THEN 'Vaticano'
#         ELSE t.nome_pais
#     END AS nome_pais_traduzido,
#
#     -- Tradução de região
#     CASE
#         WHEN t.regiao = 'Europe' THEN 'Europa'
#         ELSE t.regiao
#     END AS regiao_traduzida,
#
#     -- Tradução de subregião
#     CASE
#         WHEN t.subregiao = 'Southern Europe' THEN 'Europa do Sul'
#         WHEN t.subregiao = 'Northern Europe' THEN 'Europa do Norte'
#         WHEN t.subregiao = 'Western Europe' THEN 'Europa Ocidental'
#         WHEN t.subregiao = 'Eastern Europe' THEN 'Europa Oriental'
#         WHEN t.subregiao = 'Central Europe' THEN 'Europa Central'
#         WHEN t.subregiao = 'Southeast Europe' THEN 'Sudeste Europeu'
#         ELSE t.subregiao
#     END AS subregiao_traduzida,
#
#     -- Tradução de capital (exemplo para alguns países)
#     CASE
#         WHEN t.capital = 'Andorra La Vella' THEN 'Andorra-a-Velha'
#         WHEN t.capital = 'Tirana' THEN 'Tirana'
#         WHEN t.capital = 'Vienna' THEN 'Viena'
#         WHEN t.capital = 'Sarajevo' THEN 'Sarajevo'
#         WHEN t.capital = 'Brussels' THEN 'Bruxelas'
#         WHEN t.capital = 'Sofia' THEN 'Sófia'
#         WHEN t.capital = 'Minsk' THEN 'Minsk'
#         WHEN t.capital = 'Bern' THEN 'Berna'
#         WHEN t.capital = 'Nicosia' THEN 'Nicósia'
#         WHEN t.capital = 'Prague' THEN 'Praga'
#         WHEN t.capital = 'Berlin' THEN 'Berlim'
#         WHEN t.capital = 'Copenhagen' THEN 'Copenhague'
#         WHEN t.capital = 'Tallinn' THEN 'Tallin'
#         WHEN t.capital = 'Madrid' THEN 'Madri'
#         WHEN t.capital = 'Helsinki' THEN 'Helsinque'
#         WHEN t.capital = 'Paris' THEN 'Paris'
#         WHEN t.capital = 'London' THEN 'Londres'
#         WHEN t.capital = 'Athens' THEN 'Atenas'
#         WHEN t.capital = 'Zagreb' THEN 'Zagreb'
#         WHEN t.capital = 'Budapest' THEN 'Budapeste'
#         WHEN t.capital = 'Dublin' THEN 'Dublin'
#         WHEN t.capital = 'Reykjavik' THEN 'Reiquiavique'
#         WHEN t.capital = 'Rome' THEN 'Roma'
#         WHEN t.capital = 'Vilnius' THEN 'Vilnius'
#         WHEN t.capital = 'Luxembourg' THEN 'Luxemburgo'
#         WHEN t.capital = 'Riga' THEN 'Riga'
#         WHEN t.capital = 'Monaco' THEN 'Mônaco'
#         WHEN t.capital = 'Chișinău' THEN 'Quixinau'
#         WHEN t.capital = 'Podgorica' THEN 'Podgorica'
#         WHEN t.capital = 'Skopje' THEN 'Escópia'
#         WHEN t.capital = 'Valletta' THEN 'Valeta'
#         WHEN t.capital = 'Amsterdam' THEN 'Amsterdã'
#         WHEN t.capital = 'Oslo' THEN 'Oslo'
#         WHEN t.capital = 'Warsaw' THEN 'Varsóvia'
#         WHEN t.capital = 'Lisbon' THEN 'Lisboa'
#         WHEN t.capital = 'Bucharest' THEN 'Bucareste'
#         WHEN t.capital = 'Belgrade' THEN 'Belgrado'
#         WHEN t.capital = 'Moscow' THEN 'Moscou'
#         WHEN t.capital = 'Stockholm' THEN 'Estocolmo'
#         WHEN t.capital = 'Ljubljana' THEN 'Liubliana'
#         WHEN t.capital = 'Bratislava' THEN 'Bratislava'
#         WHEN t.capital = 'City Of San Marino' THEN 'Cidade de San Marino'
#         WHEN t.capital = 'Kyiv' THEN 'Kiev'
#         WHEN t.capital = 'Vatican City' THEN 'Cidade do Vaticano'
#         ELSE t.capital
#     END AS capital_traduzida,
#     i.pib_per_capita AS pib_per_capita,
#     i.idh * 100 AS indice_desenvolvimento_humano ,
#     i.desemprego AS taxa_desemprego,
#     i.expectativa_vida AS expectativa_de_vida,
#     i.co2_per_capita AS co2_per_capita,
#     i.energia_renovavel_pct AS energia_renovavel_percentual,
#     i.internet_pc AS internet_porcentagem,
#
#     -- Tradução de nome_pais
#
#
#     -- Mantém os demais campos
#     t.populacao,
#     t.area_km2,
#     t.flag AS bandeira,
#     t.independencia,
#     t.membro_Onu AS membro_onu,
#     t.sem_saida_para_o_mar,
#     CASE
#     WHEN t.dia_inicial_semana = 'Monday' THEN 'Segunda-Feira'
#     END AS Dia_inicial,
#     t.codigo_fifa,
#     t.latitude,
#     t.longitude,
#
#     -- Indicadores derivados
#
#     t.populacao / NULLIF(t.area_km2, 0) AS densidade_demografica,
#     i.pib_per_capita * t.populacao AS pib_total_estimado,
#     i.co2_per_capita * t.populacao AS co2_total_estimado,
#     (i.internet_pc / 100.0) * t.populacao AS pessoas_com_internet,
#
#     -- Classificações
#     CASE
#         WHEN i.idh >= 0.8 THEN 'Alto'
#         WHEN i.idh >= 0.5 THEN 'Médio'
#         ELSE 'Baixo'
#     END AS faixa_idh,
#
#     CASE
#         WHEN i.pib_per_capita >= 30000 THEN 'Alto'
#         WHEN i.pib_per_capita >= 10000 THEN 'Médio'
#         ELSE 'Baixo'
#     END AS faixa_pib_per_capita,
#
#     CASE
#         WHEN i.energia_renovavel_pct >= 50 THEN 'Alta'
#         WHEN i.energia_renovavel_pct >= 20 THEN 'Média'
#         ELSE 'Baixa'
#     END AS classificacao_energia_limpa,
#
#     -- Índice composto de desenvolvimento sustentável
#     (i.idh * 0.4
#      + (100 - i.desemprego) * 0.2
#      + i.energia_renovavel_pct * 0.2
#      + i.internet_pc * 0.2) AS indice_sustentavel
#
# FROM
#     tabela_paises AS t
# JOIN
#     informacoes_paises AS i
# ON
#     t.codigo_iso_2 = i.codigo_iso_2;
# Out:
# StatementMeta(, 2d495d51-73dc-401e-b110-178ec65bed8d, 13, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
#
# select * from paises_gold_vw;
# Out:
# StatementMeta(, 2d495d51-73dc-401e-b110-178ec65bed8d, 14, Finished, Available, Finished)
# <Spark SQL result set with 8 rows and 30 fields>

# %%
 # %%sql
 CREATE OR REPLACE TABLE paises_gold
 USING DELTA
 AS
 SELECT *
 FROM paises_gold_vw;
# Out:
# StatementMeta(, 2d495d51-73dc-401e-b110-178ec65bed8d, 15, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from paises_gold;
# Out:
# StatementMeta(, 2d495d51-73dc-401e-b110-178ec65bed8d, 16, Finished, Available, Finished)
# <Spark SQL result set with 8 rows and 30 fields>
